# %%
import math, sys, os, requests
import numpy as np
from os import path
from pathlib import Path
from functools import reduce
import gzip

sys.path.append("./bin")
os.environ["BIOSHELL_DATA_DIR"] = './data'

from pybioshell.core.data.io import Pdb, Cif
from pybioshell.core.chemical import PdbMolecule
from pybioshell.core.chemical import find_rings
from pybioshell.core.data.structural.selectors import SelectResidueByName, ChainSelector, SelectChainResidues
from pybioshell.core.calc.structural import SaturatedRing6Geometry
from pybioshell.core.chemical import MonomerStructure


#from google.colab import files
#uploaded = files.upload()

def extract_ligand(pdb_file_name, ligand_name, cutoff_distance):
    #check if the file is not empty
    if os.stat(pdb_file_name).st_size == 0:
        print(pdb_file_name, "has", os.stat(pdb_file_name).st_size)
        return
    #read file as bioshell structure without hydrogens and alternative atom positions
    if os.stat(pdb_file_name).st_size == 0:
        print(pdb_file_name, "has", os.stat(pdb_file_name).st_size)
        return
    s = Pdb(str(pdb_file_name), "is_not_hydrogen is_not_alternative", False, False).create_structure(0)
    ligands = []
    for ic in range(s.count_chains()):
        chain = s[ic]
        for ir in range(chain.count_residues()):
            if chain[ir].residue_type().code3 == ligand_name:
                ligands.append(chain[ir])
    for l in ligands:
        fname = "%s-%d-%s-%s.pdb" % (l.residue_type().code3, l.id(), l.owner().id(), s.code())
        fout = open(fname, "w")

        for ic in range(s.count_chains()):
            chain = s[ic]
            for ir in range(chain.count_residues()):
                r = chain[ir]
                if r.min_distance(l) < cutoff_distance:
                    if r.id() == l.id():
                        for ai in range(r.count_atoms()):
                            fout.write(r[ai].to_pdb_line() + "\n")
                    if r.residue_type().code3 != l.residue_type().code3:
                        for ai in range(r.count_atoms()):
                            fout.write(r[ai].to_pdb_line() + "\n")

        #full CONNECT section from pdb file is added to the ligand's pdb - it is crucial to define rings
        for line in open(pdb_file_name).readlines():
            if line.startswith("CONECT"):
                fout.write(line)

        fout.close()
        return l, fname


def download_ideal_cif(ligand_code):
    try:
        r = requests.get("https://files.rcsb.org/ligands/download/%s.cif" % ligand_code, allow_redirects=True)
        #r = requests.get("https://files.rcsb.org/ligands/download/%s_ideal.sdf" % ligand_code, allow_redirects=True)
        open(ligand_code + ".cif", "wb").write(r.content)
    except Exception as error:
        print("An issue occurred during", ligand_code, "downloading", error)
    mm = MonomerStructure.from_cif(ligand_code + ".cif")
    return mm

def load_atoms_counts(fname):
    f = open(fname)
    for i in range(3): f.readline()
    tokens = f.readline().strip().split()
    n = int(tokens[0][0:3])
    number_of_atoms = 0
    for i in range(n):
        line = f.readline()
        try:
            if line[31] != 'H':
                number_of_atoms += 1
        except Exception as error:
            print("Some error occurred", line, error)

    return number_of_atoms


def dihedral(p):
    """https://stackoverflow.com/questions/20305272/dihedral-torsion-angle-from-four-points-in-cartesian-coordinates-in-python"""
    b = p[:-1] - p[1:]
    b[0] *= -1
    v = np.array([v - (v.dot(b[1]) / b[1].dot(b[1])) * b[1] for v in [b[0], b[2]]])
    # Normalize vectors
    v /= np.sqrt(np.einsum('...i,...i', v, v)).reshape(-1, 1)
    b1 = b[1] / np.linalg.norm(b[1])
    x = np.dot(v[0], v[1])
    m = np.cross(v[0], b1)
    y = np.dot(m, v[1])
    return np.degrees(np.arctan2(y, x))


def collect_atoms(molecule, ring_element):
    ring_atoms = []
    for atom_i in ring_element:
        atom = molecule.get_atom(atom_i)
        ring_atoms.append(atom)
    atom = molecule.get_atom(6)
    ring_atoms.append(atom)
    atom = molecule.get_atom(9)
    ring_atoms.append(atom)
    return ring_atoms


def calculate_bonds(ring_atoms, at_number):
    try:
        bond = ring_atoms[at_number].distance_to(ring_atoms[at_number + 1])
    except:
        bond = ring_atoms[at_number].distance_to(ring_atoms[0])
    return bond


def calculate_reference_bonds(ligand, ring_element):
    ideal_atoms = collect_atoms(ligand, ring_element)
    ideal_bonds = []
    for i in range(len(ideal_atoms)):
        ideal_bonds.append(calculate_bonds(ideal_atoms, i))
    return ideal_bonds


def average(lst):
    return sum(lst) / len(lst)


def conf_check(wings):
    if wings > 0:
        conf = "boat"
    elif wings < 0:
        conf = "chair"
    else:
        conf = "Error! Flat"
    return conf


def bonds_statistics(number_of_atoms, ligand_name, conformation_name, angle_twist, sigma_dev):
    ligand_bonds = []
    ligand_bonds_err = []
    ideal_bonds = ""
    twist_err = ""
    if conformation_name == "chair":
        ideal_bonds, twist_err = ideal_ligand_geometry(angle_twist, ligand_name, '.cif')
    elif conformation_name == "boat":
        ideal_bonds1, twist_err1 = ideal_ligand_geometry(angle_twist, ligand_name, 'cif')
        ideal_bonds2, twist_err2 = ideal_ligand_geometry(angle_twist, ligand_name, '.cif')
        if min(abs(twist_err2), abs(twist_err1)) == twist_err1:
            ideal_bonds = ideal_bonds1
            twist_err = twist_err1
        else:
            ideal_bonds = ideal_bonds2
            twist_err = twist_err2
    if np.degrees(abs(twist_err)) > sigma_dev:
        conformation_name = "twist_" + conformation_name
    for i in range(len(number_of_atoms)):
        ligand_bonds.append(calculate_bonds(number_of_atoms, i))
    for b in range(len(ligand_bonds)):
        try:
            ligand_bonds_err.append(ligand_bonds[b] - ideal_bonds[b])
        except Exception as error:
            ligand_bonds_err.append(ligand_bonds[b] - ideal_bonds[-1])
    return ligand_bonds, ligand_bonds_err, twist_err, conformation_name


def ideal_ligand_geometry(angle_twist, ligand_name, filename):
    ideal_structure = MonomerStructure.from_cif(ligand_name + filename)
    ideal_bonds = calculate_reference_bonds(ideal_structure, find_rings(ideal_structure)[0])
    ideal_ring = find_rings(ideal_structure)[0]
    ideal_atoms = collect_atoms(ideal_structure, ideal_ring)
    print(ideal_atoms[0])
    f = SaturatedRing6Geometry(ideal_atoms[0], ideal_atoms[1], ideal_atoms[2], ideal_atoms[3], ideal_atoms[4],
                               ideal_atoms[5])
    ideal_twist = f.twist_angle()
    twist_err = angle_twist - ideal_twist
    return ideal_bonds, twist_err


def atoms_bfactor(bioshell_residue):
    atoms_bf = []
    for atom in range(bioshell_residue.count_atoms()):
        atom_bf = bioshell_residue.get_atom(atom).b_factor()  # residue_type().n_atoms):
        atoms_bf.append("{:3.2f}".format(float(atom_bf)))
    return float(min(atoms_bf)), float(max(atoms_bf)), float(round(avg(atoms_bf), 2))


def avg(lst):
    return reduce(lambda a, b: float(a) + float(b), lst) / len(lst)


if __name__ == "__main__":
    code = 'EPE'
    pdb_file = '7ol5.pdb'
    distance = 5
    ligand_in_file, fname = extract_ligand(pdb_file, code, distance)
    chain_name = ligand_in_file.back().chain_id
    res_id = ligand_in_file.id()
    chain_sel = ChainSelector(chain_name)
    ligand_sel = SelectResidueByName(code)
    filter_ligand = SelectChainResidues(chain_sel, ligand_sel)
    mol = PdbMolecule.from_pdb(fname, filter_ligand)
    ideal = download_ideal_cif('EPE')
    n_atoms = ideal.n_heavy_atoms
    sigma = 10.0  # based on https://doi.org/10.1016/j.str.2021.02.004 a 10 deg is used as deviation
    #fname = sys.argv[1]
    chain_name = fname.split("-")[2]
    code = fname.split("-")[0]
    res_id = fname.split("-")[1]
    pdb_id = fname.split("-")[3][0:4]
    #n_atoms = load_atoms_counts(PATH_TO_IDEAL_SDF + code + "_ideal.sdf")
    chain_sel = ChainSelector(chain_name)
    ligand_sel = SelectResidueByName(code)
    filter_ligand = SelectChainResidues(chain_sel, ligand_sel)
    mol = PdbMolecule.from_pdb(fname, filter_ligand)
    if mol.count_atoms() != n_atoms:
        print("Too few atoms in %s! Expected: %d Found: %d" % (fname, n_atoms, mol.count_atoms()), file=sys.stderr)
        with open(missing_atoms_file, "a") as missing_file:
            print("{:4s} {:4s} {:2s} {:3s} {:3s} {:3d} {:3d}".format(
                fname, pdb_id, chain_name, res_id, code, n_atoms, mol.count_atoms()), file=missing_file)
        sys.exit(0)

    rings = find_rings(mol)
    if len(rings) == 0:
        print("No rings found in", fname, file=sys.stderr)

    bf_min, bf_max, bf_avg = atoms_bfactor(mol)

    for ring in rings:
        if len(ring) != 6:
            print("Ring length differs from 6", fname, file=sys.stderr)
            sys.exit(0)
        atoms = collect_atoms(mol, ring)

        points = [np.array([atoms[i].x, atoms[i].y, atoms[i].z]) for i in range(8)]

        t1 = dihedral(np.array(points[0:4]))
        t2 = dihedral(np.array(points[1:5]))
        t3 = dihedral(np.array(points[2:6]))
        points = [np.array([atoms[i].x, atoms[i].y, atoms[i].z]) for i in [1, 2, 3, 6]]
        t4 = dihedral(np.array(points[0:4]))
        points = [np.array([atoms[i].x, atoms[i].y, atoms[i].z]) for i in [2, 1, 0, 7]]
        t5 = dihedral(np.array(points[0:4]))
        g = SaturatedRing6Geometry(atoms[0], atoms[1], atoms[2], atoms[3], atoms[4], atoms[5])

        w1_w2 = g.first_wing_angle() * g.second_wing_angle()
        twist_angle = g.twist_angle()
        conformation = conf_check(w1_w2)
        #bonds, bonds_err, twist_angle_err, conformation = bonds_statistics(atoms, code, conformation, twist_angle,
        #                                                                   sigma)
        #print(fname, pdb_id, chain_name, res_id, code, conformation, g.first_wing().atom_name(),
        #      g.second_wing().atom_name())
# Out:
#     [FILE] Pdb Reading PDB from: 7ol5.pdb
#     [FILE] BioShellEnvironment file ./data/monomers.txt found in BioShell DB location: ./data
#     [INFO] Pdb Found 1 models, 1130 atoms each after 6 [ms]
#     [FILE] BioShellEnvironment file ./data/monomers.txt found in BioShell DB location: ./data
#     [INFO] Pdb Found 1 models, 119 atoms each after 4 [ms]
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 98. It will not be connected to anything. The incorrect CONECT record was:
# CONECT   98 1961 1961 1961 1961
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 469. It will not be connected to anything. The incorrect CONECT record was:
# CONECT  469 1796 1796 1796 1796
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1007. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1007 1235 1235 1235 1235
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1177. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1177 1423 1423 1423 1423
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1235. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1235 1007 1007 1007 1007
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1423. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1423 1177 1177 1177 1177
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1796. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1796  469  469  469  469
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1961. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1961   98   98   98   98
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1991. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1991 1992 1995 1996 1997
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1992. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1992 1991 1993 1994 1998
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1993. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1993 1992 1999 2000 2001
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1994. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1994 1992 2002 2002 2002
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1995. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1995 1991 1991 1991 1991
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1996. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1996 1991 1991 1991 1991
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1997. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1997 1991 1991 1991 1991
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1998. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1998 1992 1992 1992 1992
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1999. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1999 1993 1993 1993 1993
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2000. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2000 1993 1993 1993 1993
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2001. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2001 1993 1993 1993 1993
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2002. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2002 1994 1994 1994 1994
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2018. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2019. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2020. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2021. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2022. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2023. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2024. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2025. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2026. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2027. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2028. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2029. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2031. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2032. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2033. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2034. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2018. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2018 2004 2004 2004 2004
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2019. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2019 2004 2004 2004 2004
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2020. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2020 2005 2005 2005 2005
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2021. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2021 2005 2005 2005 2005
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2022. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2022 2007 2007 2007 2007
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2023. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2023 2007 2007 2007 2007
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2024. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2024 2008 2008 2008 2008
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2025. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2025 2008 2008 2008 2008
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2026. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2026 2009 2009 2009 2009
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2027. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2027 2009 2009 2009 2009
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2028. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2028 2010 2010 2010 2010
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2029. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2029 2010 2010 2010 2010
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2030 2011 2011 2011 2011
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2031. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2031 2012 2012 2012 2012
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2032. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2032 2012 2012 2012 2012
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2033. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2033 2013 2013 2013 2013
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2034. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2034 2013 2013 2013 2013
#     [INFO] Cif 1 block(s) found in the input
#     [FILE] BioShellEnvironment file ./data/monomers.txt found in BioShell DB location: ./data
#     [INFO] Pdb Found 1 models, 119 atoms each after 7 [ms]
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 98. It will not be connected to anything. The incorrect CONECT record was:
# CONECT   98 1961 1961 1961 1961
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 469. It will not be connected to anything. The incorrect CONECT record was:
# CONECT  469 1796 1796 1796 1796
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1007. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1007 1235 1235 1235 1235
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1177. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1177 1423 1423 1423 1423
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1235. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1235 1007 1007 1007 1007
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1423. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1423 1177 1177 1177 1177
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1796. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1796  469  469  469  469
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1961. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1961   98   98   98   98
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1991. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1991 1992 1995 1996 1997
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1992. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1992 1991 1993 1994 1998
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1993. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1993 1992 1999 2000 2001
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1994. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1994 1992 2002 2002 2002
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1995. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1995 1991 1991 1991 1991
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1996. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1996 1991 1991 1991 1991
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1997. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1997 1991 1991 1991 1991
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1998. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1998 1992 1992 1992 1992
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 1999. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 1999 1993 1993 1993 1993
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2000. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2000 1993 1993 1993 1993
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2001. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2001 1993 1993 1993 1993
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2002. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2002 1994 1994 1994 1994
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2018. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2019. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2020. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2021. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2022. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2023. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2024. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2025. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2026. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2027. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2028. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2029. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2031. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2032. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2033. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2034. It will not be connected to anything
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2018. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2018 2004 2004 2004 2004
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2019. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2019 2004 2004 2004 2004
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2020. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2020 2005 2005 2005 2005
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2021. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2021 2005 2005 2005 2005
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2022. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2022 2007 2007 2007 2007
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2023. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2023 2007 2007 2007 2007
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2024. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2024 2008 2008 2008 2008
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2025. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2025 2008 2008 2008 2008
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2026. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2026 2009 2009 2009 2009
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2027. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2027 2009 2009 2009 2009
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2028. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2028 2010 2010 2010 2010
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2029. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2029 2010 2010 2010 2010
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2030. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2030 2011 2011 2011 2011
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2031. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2031 2012 2012 2012 2012
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2032. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2032 2012 2012 2012 2012
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2033. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2033 2013 2013 2013 2013
#  [WARNING] PdbMolecule::from_pdb can't find atom of ID: 2034. It will not be connected to anything. The incorrect CONECT record was:
# CONECT 2034 2013 2013 2013 2013
